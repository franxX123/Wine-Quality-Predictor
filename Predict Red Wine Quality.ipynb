# %% [markdown]
# ## Project - Applying Data Science Methodology on Red Wine Quality Dataset
#
# <img src="https://media.giphy.com/media/jRuv9xc10lVyE/giphy.gif">
#
# You can read more about the Data Science Methodology from this [IBM whitepaper](https://tdwi.org/~/media/64511A895D86457E964174EDC5C4C7B1.PDF) by John Rollins
#
# [Link](https://archive.ics.uci.edu/ml/datasets/wine+quality) for the dataset for context
#
# <img src="https://media-exp1.licdn.com/dms/image/C4D12AQGOPVf5iqhhwQ/article-inline_image-shrink_1000_1488/0/1597756152693?e=1652918400&v=beta&t=iKZ2jX3khsx11lD9JyZWDz-j-Gt2hZsKPXz5rZ0iE1M">

# %% [markdown]
# ### Business Understanding
#
# The red wine industry shows a recent exponential growth as social drinking is on the rise. Nowadays, industry players are using product quality certifications to promote their products. This is a time-consuming process and requires the assessment given by human experts, which makes this process very expensive. Also, the price of red wine depends on a rather abstract concept of wine appreciation by wine tasters, opinion among whom may have a high degree of variability. Another vital factor in red wine certification and quality assessment is physicochemical tests, which are laboratory-based and consider factors like acidity, pH level, sugar, and other chemical properties. The red wine market would be of interest if the human quality of tasting can be related to wine’s chemical properties so that certification and quality assessment and assurance processes are more controlled.
#
# The goal is to implement Regression Models and Classification Models on the Red Wine Quality Dataset to determine which features are the best quality red wine indicators and generate insights into each of these factors to our model’s red wine quality.

# %% [markdown]
# ### Analytic Approach
# Based on the above business understanding one should decide the analytical approach to follow. The approaches can be of 4 types: Descriptive approach (current status and information provided), Diagnostic approach(a.k.a statistical analysis, what is happening and why it is happening), Predictive approach(it forecasts on the trends or future events probability) and Prescriptive approach( how the problem should be solved actually).
#
# **Q1. What is the analytical approach that you would take for this project? Why do you think its the right approach?**
#
# *TODO*
#
# Answer: I would take a Predictive Approach for this project since the task requires that we make a prediction about the quality of wine, which will be facilitated using the data provided through the use of analytical methods for finding the trends in the data. This approach will include looking at some correlations between the different features in the data and removing these correlated features to make sure that the model's accuracy doesn't get affected, removing or replacing certain feature values, engineering more features and analyzing trends related to these features, and then using the preprocessed data to feed to a model to learn the underlying pattern and make a suitable prediction.

# %% [markdown]
# ### Data Requirements
#
# **Q2. What kind of data do we require for predicting the red wine quality and for determining the features that are the best quality red wine indicators?**
#
# *TODO*
#
# For this problem it is instrumental that we have floating point and integer typed values as the type of our features to leverage effective machine learning models.

# %% [markdown]
# ### Data Collection
#
# **Q3. From where do we get our data?**
#
# *TODO*
# We will be using the dataset winequality-red.csv as provided by the instructor, and can be found in the following link:
# https://archive.ics.uci.edu/ml/datasets/wine+quality.

# %% [markdown]
# ### Data Understanding
#
# Link for the dataset https://archive.ics.uci.edu/ml/datasets/wine+quality for context
#
# **Q4. From where are red wine samples obtained?**
#
# ANSWER: According to the website https://archive.ics.uci.edu/ml/datasets/wine+quality, the dataset provided about red vinho verde wine samples was taken from the north of Portugal, and donated in 2009 to the website mentioned above.
#
#
# **Q5. How can knowing the impact of each variable on the red wine quality help businesses(producers, distributors, etc) ?**
#
# ANSWER: By knowing the impact of each variable in the wine we can derive the most important factors in creating quality wine, as a result wine makers can improve their wine creation process by reducing certain factors and increasing others, which is helpful for setting prices.
#
# *TODO*
#
# *TODO*
# <li>Check the shape of data, and the datatypes of the features</li>
# <li>Understand the data by carrying out any steps that you think are necessary</li>

# %%
import calendar
import numpy as np
import pandas as pd
import seaborn as sn
import missingno as msno
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore", category=DeprecationWarning)

wine_data = pd.read_csv("winequality-red.csv", sep=",")
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Data Preparation
#
# #### Explore the dataset further
# *TODO*
# <li>Check for missing values and handle if any</li>
# <li>Check for outliers if any and handle them</li>
# <li>Implement Correlation heatmap</li>
# <li>Check the distribution of data using histograms</li>
# <li>Prepare the data for modeling by carrying out any steps that you think are necessary</li>

# %% [markdown]
# <li>Check for missing values and handle if any</li>
# From the graph below we notice there are no missing values for any features

# %%
msno.matrix(wine_data,figsize=(10,3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <li>Check for outliers if any and handle them</li>

# %%
fig, axes = plt.subplots(nrows=4,ncols=1)
fig.set_size_inches(10, 30)
sn.boxplot(data=wine_data,orient="v",ax=axes[0])
sn.boxplot(data=wine_data,y="quality",orient="v",ax=axes[1])
sn.boxplot(data=wine_data,y="quality",x="residual sugar",orient="v",ax=axes[2])
sn.boxplot(data=wine_data,y="quality",x="pH",orient="v",ax=axes[3])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %% [markdown]
# <p>In the following cell we removed the outliers by finding the absolute value of the z-score for each column. This means we represent the values each cell as the number of standard deviation away from the mean for their respective features/columns. Then we filter out the cells with z-scores greater than threshold which I defined to be 3 since, by theory, most data points (99.8% of data points) must exist 3 standard deviations away from the mean. Thus, anything greater than this threshold must then be an outlier. </p>

# %%
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(wine_data))
print(z.shape)
# print(np.where(z > 3))
# print(z[13][9])
# print(z[55])
# Out:
# (1599, 12)

# %%
threshold = 3
wine_data = wine_data[(z < threshold).all(axis=1)]
wine_data.shape
# Out:
# (1451, 12)

# %% [markdown]
# <li>Implement Correlation heatmap</li>

# %%
# Correlation analysis
corrMatt = wine_data.corr()
mask = np.array(corrMatt)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sn.heatmap(corrMatt, mask=mask,vmax=.8, square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <li>Check the distribution of data using histograms</li>

# %%
sn.set_style('whitegrid')
sn.pairplot(wine_data)

# %% [markdown]
# ### Modeling
#
# *TODO*
# <li>Implement Multivariable Linear Regression using any 2 Regression algorithms of your choice</li>
#
# <p>For this question, I will use Random Forest and SVM as my multivariable regression algorithms.</p>
#
# <li>Implement a Neural Network using Tensorflow and Keras to classify wine quality</li>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, LabelEncoder

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

features = wine_data.drop('quality', axis=1)
labels = wine_data['quality']
# labels.shape
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(features, labels,test_size=test_size, random_state=1)

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
X_train.shape
# Out:
# (1160, 11)

# %%
y_train.shape
# Out:
# (1160,)

# %%
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %% [markdown]
# ### Multiple Linear Regression: Support Vector Machine

# %%
svc = SVR()
parameters = {
    'kernel': ['rbf'],
    'C': [0.1, 1, 10]
}

cv = GridSearchCV(svc, parameters, cv=5)
cv.fit(X_train, y_train.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'C': 1, 'kernel': 'rbf'}
#
# 0.378 (+/-0.079) for {'C': 0.1, 'kernel': 'rbf'}
# 0.414 (+/-0.104) for {'C': 1, 'kernel': 'rbf'}
# 0.306 (+/-0.112) for {'C': 10, 'kernel': 'rbf'}

# %%
best_svc = cv.best_estimator_

# %%
y_pred_svc = best_svc.predict(X_test)

# %%
len(y_pred_svc)
# Out:
# 291

# %% [markdown]
# ### Multiple Linear Regression: Random Forest

# %%
rf = RandomForestRegressor()
parameters = {
    'n_estimators': [5, 50, 250],
    'max_depth': [2, 4, 8, 16, 32, None]
}

cv = GridSearchCV(rf, parameters, cv=10)
cv.fit(X_train, y_train)

print_results(cv)
# Out:
# BEST PARAMS: {'max_depth': 32, 'n_estimators': 250}
#
# 0.298 (+/-0.12) for {'max_depth': 2, 'n_estimators': 5}
# 0.313 (+/-0.1) for {'max_depth': 2, 'n_estimators': 50}
# 0.315 (+/-0.101) for {'max_depth': 2, 'n_estimators': 250}
# 0.364 (+/-0.161) for {'max_depth': 4, 'n_estimators': 5}
# 0.387 (+/-0.144) for {'max_depth': 4, 'n_estimators': 50}
# 0.39 (+/-0.14) for {'max_depth': 4, 'n_estimators': 250}
# 0.342 (+/-0.24) for {'max_depth': 8, 'n_estimators': 5}
# 0.453 (+/-0.198) for {'max_depth': 8, 'n_estimators': 50}
# 0.457 (+/-0.204) for {'max_depth': 8, 'n_estimators': 250}
# 0.375 (+/-0.246) for {'max_depth': 16, 'n_estimators': 5}
# 0.484 (+/-0.211) for {'max_depth': 16, 'n_estimators': 50}
# 0.482 (+/-0.222) for {'max_depth': 16, 'n_estimators': 250}
# 0.357 (+/-0.259) for {'max_depth': 32, 'n_estimators': 5}
# 0.479 (+/-0.235) for {'max_depth': 32, 'n_estimators': 50}
# 0.488 (+/-0.218) for {'max_depth': 32, 'n_estimators': 250}
# 0.39 (+/-0.269) for {'max_depth': None, 'n_estimators': 5}
# 0.486 (+/-0.231) for {'max_depth': None, 'n_estimators': 50}
# 0.481 (+/-0.217) for {'max_depth': None, 'n_estimators': 250}

# %%
rf = RandomForestRegressor(random_state=1, max_depth=16, n_estimators=250)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=16, n_estimators=250, random_state=1)

# %%
y_pred_rf = rf.predict(X_test)

# %%
len(y_pred_rf)
# Out:
# 291

# %% [markdown]
# #### As a slight detour, let's also generate a figure showing the most important features for the Random Forest to see which features we should include in creating an NN.

# %%
rf_temp = RandomForestRegressor(random_state=1, max_depth=12)
x = wine_data.drop(['quality'] , axis = 1)
temp_wine_data = pd.get_dummies(wine_data)
rf_temp.fit(features, wine_data['quality'])
display(rf_temp.feature_importances_)
# Out:
# array([0.04197691, 0.10182017, 0.06032171, 0.05195373, 0.06338062,
#        0.03991618, 0.08013138, 0.04856052, 0.0586216 , 0.14883862,
#        0.30447857])

# %%
features = temp_wine_data.columns
importances = rf_temp.feature_importances_
indices = np.argsort(importances)[:]
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices])
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Importance')
plt.show()

# %% [markdown]
# ### Note: We will use the features with the lowest importance as indicated in the figure above. More specifically, density, fixed acidity, and free sulfur dioxide.

# %% [markdown]
# ## Artificial Neural Network

# %% [markdown]
# ### Let's start fresh by importing the wine data again

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import StandardScaler, LabelEncoder

wine_data = pd.read_csv("winequality-red.csv", sep=",")
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# #### We remove the outliers

# %%
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(wine_data))
print(z.shape)
# Out:
# (1599, 12)

# %%
threshold = 3
wine_data = wine_data[(z < threshold).all(axis=1)]
wine_data.shape
# Out:
# (1451, 12)

# %%
x = wine_data.drop(['quality'] , axis = 1)

# %%
del x['fixed acidity']
del x['free sulfur dioxide']
del x['citric acid']

# %%
from collections import Counter

le = LabelEncoder()
y = le.fit_transform(wine_data.iloc[: , -1]) # in row form
print(Counter(y))
y = pd.DataFrame(y.reshape(len(y),1))
# Out:
# Counter({1: 617, 2: 586, 3: 185, 0: 47, 4: 16})

# %% [markdown]
# #### Notice that the minority of the data is under-represented from the counter shown above. This is important to address because having a massive imbalance between majority and minority classes can introduce a bias towards the majority classes. To address this problem I will bring in an over-sampling tool called SMOTE. This will allow us to produce more balanced data for each class by specifying certain parameters like the sampling strategy which allows us to map a certain number of data points corresponding to each class label. Note: the sample size I decided on was based on trial and error, the provided sample size is simply the one that seemed to give me the best results.

# %%
from imblearn.over_sampling import SMOTE

sample_size = 1800
oversample = SMOTE(sampling_strategy={0: sample_size, 1: sample_size, 2: sample_size, 3: sample_size, 4: sample_size})
x, y = oversample.fit_resample(x, y)
# Out:
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 0 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 1 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 2 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 3 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 4 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
x_train_nn, x_test_nn, y_train_nn, y_test_nn = train_test_split(x, y, test_size = 0.2, random_state = 132)

# %%
n_classes = 6 # because we only have 6 categories
y_train_cat = tf.keras.utils.to_categorical(y_train_nn, n_classes)
y_test_cat = tf.keras.utils.to_categorical(y_test_nn, n_classes)

# %%
sc = StandardScaler()

x_train_nn = sc.fit_transform(x_train_nn)
x_test_nn = sc.fit_transform(x_test_nn)

# %%
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(8,)))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(6, activation='sigmoid'))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics= ['accuracy'])

# %%
history = model.fit(x_train_nn, y_train_cat,  batch_size=32, epochs = 50 , validation_data = (x_test_nn, y_test_cat))
# Out:
# Epoch 1/50
# 225/225 [==============================] - 1s 1ms/step - loss: 1.3909 - accuracy: 0.4283 - val_loss: 1.0747 - val_accuracy: 0.5700
# Epoch 2/50
# 225/225 [==============================] - 0s 906us/step - loss: 1.0188 - accuracy: 0.5619 - val_loss: 0.9450 - val_accuracy: 0.6206
# Epoch 3/50
# 225/225 [==============================] - 0s 933us/step - loss: 0.9315 - accuracy: 0.6129 - val_loss: 0.8816 - val_accuracy: 0.6344
# Epoch 4/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.8798 - accuracy: 0.6325 - val_loss: 0.8317 - val_accuracy: 0.6583
# Epoch 5/50
# 225/225 [==============================] - 0s 866us/step - loss: 0.8392 - accuracy: 0.6472 - val_loss: 0.7994 - val_accuracy: 0.6689
# Epoch 6/50
# 225/225 [==============================] - 0s 924us/step - loss: 0.8088 - accuracy: 0.6600 - val_loss: 0.7717 - val_accuracy: 0.6844
# Epoch 7/50
# 225/225 [==============================] - 0s 942us/step - loss: 0.7842 - accuracy: 0.6722 - val_loss: 0.7599 - val_accuracy: 0.6789
# Epoch 8/50
# 225/225 [==============================] - 0s 937us/step - loss: 0.7665 - accuracy: 0.6789 - val_loss: 0.7369 - val_accuracy: 0.6972
# Epoch 9/50
# 225/225 [==============================] - 0s 929us/step - loss: 0.7520 - accuracy: 0.6835 - val_loss: 0.7350 - val_accuracy: 0.6978
# Epoch 10/50
# 225/225 [==============================] - 0s 915us/step - loss: 0.7409 - accuracy: 0.6897 - val_loss: 0.7186 - val_accuracy: 0.7044
# Epoch 11/50
# 225/225 [==============================] - 0s 906us/step - loss: 0.7291 - accuracy: 0.6931 - val_loss: 0.7070 - val_accuracy: 0.7122
# Epoch 12/50
# 225/225 [==============================] - 0s 911us/step - loss: 0.7197 - accuracy: 0.6993 - val_loss: 0.7012 - val_accuracy: 0.7122
# Epoch 13/50
# 225/225 [==============================] - 0s 942us/step - loss: 0.7117 - accuracy: 0.7043 - val_loss: 0.6858 - val_accuracy: 0.7172
# Epoch 14/50
# 225/225 [==============================] - 0s 933us/step - loss: 0.7023 - accuracy: 0.7067 - val_loss: 0.6810 - val_accuracy: 0.7189
# Epoch 15/50
# 225/225 [==============================] - 0s 866us/step - loss: 0.6955 - accuracy: 0.7097 - val_loss: 0.6769 - val_accuracy: 0.7194
# Epoch 16/50
# 225/225 [==============================] - 0s 902us/step - loss: 0.6884 - accuracy: 0.7125 - val_loss: 0.6731 - val_accuracy: 0.7300
# Epoch 17/50
# 225/225 [==============================] - 0s 893us/step - loss: 0.6829 - accuracy: 0.7131 - val_loss: 0.6634 - val_accuracy: 0.7306
# Epoch 18/50
# 225/225 [==============================] - 0s 848us/step - loss: 0.6754 - accuracy: 0.7206 - val_loss: 0.6549 - val_accuracy: 0.7356
# Epoch 19/50
# 225/225 [==============================] - 0s 902us/step - loss: 0.6708 - accuracy: 0.7240 - val_loss: 0.6517 - val_accuracy: 0.7350
# Epoch 20/50
# 225/225 [==============================] - 0s 871us/step - loss: 0.6657 - accuracy: 0.7258 - val_loss: 0.6566 - val_accuracy: 0.7278
# Epoch 21/50
# 225/225 [==============================] - 0s 844us/step - loss: 0.6607 - accuracy: 0.7283 - val_loss: 0.6475 - val_accuracy: 0.7350
# Epoch 22/50
# 225/225 [==============================] - 0s 857us/step - loss: 0.6573 - accuracy: 0.7301 - val_loss: 0.6385 - val_accuracy: 0.7444
# Epoch 23/50
# 225/225 [==============================] - 0s 879us/step - loss: 0.6541 - accuracy: 0.7304 - val_loss: 0.6361 - val_accuracy: 0.7400
# Epoch 24/50
# 225/225 [==============================] - 0s 862us/step - loss: 0.6483 - accuracy: 0.7332 - val_loss: 0.6273 - val_accuracy: 0.7467
# Epoch 25/50
# 225/225 [==============================] - 0s 906us/step - loss: 0.6450 - accuracy: 0.7361 - val_loss: 0.6392 - val_accuracy: 0.7433
# Epoch 26/50
# 225/225 [==============================] - 0s 862us/step - loss: 0.6414 - accuracy: 0.7390 - val_loss: 0.6308 - val_accuracy: 0.7444
# Epoch 27/50
# 225/225 [==============================] - 0s 888us/step - loss: 0.6375 - accuracy: 0.7449 - val_loss: 0.6188 - val_accuracy: 0.7506
# Epoch 28/50
# 225/225 [==============================] - 0s 911us/step - loss: 0.6333 - accuracy: 0.7429 - val_loss: 0.6166 - val_accuracy: 0.7561
# Epoch 29/50
# 225/225 [==============================] - 0s 893us/step - loss: 0.6300 - accuracy: 0.7450 - val_loss: 0.6195 - val_accuracy: 0.7544
# Epoch 30/50
# 225/225 [==============================] - 0s 848us/step - loss: 0.6274 - accuracy: 0.7472 - val_loss: 0.6113 - val_accuracy: 0.7589
# Epoch 31/50
# 225/225 [==============================] - 0s 924us/step - loss: 0.6233 - accuracy: 0.7499 - val_loss: 0.6256 - val_accuracy: 0.7483
# Epoch 32/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.6221 - accuracy: 0.7506 - val_loss: 0.6118 - val_accuracy: 0.7511
# Epoch 33/50
# 225/225 [==============================] - 0s 915us/step - loss: 0.6168 - accuracy: 0.7521 - val_loss: 0.6052 - val_accuracy: 0.7594
# Epoch 34/50
# 225/225 [==============================] - 0s 853us/step - loss: 0.6142 - accuracy: 0.7540 - val_loss: 0.6119 - val_accuracy: 0.7417
# Epoch 35/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.6123 - accuracy: 0.7514 - val_loss: 0.6070 - val_accuracy: 0.7639
# Epoch 36/50
# 225/225 [==============================] - 0s 871us/step - loss: 0.6097 - accuracy: 0.7575 - val_loss: 0.5997 - val_accuracy: 0.7661
# Epoch 37/50
# 225/225 [==============================] - 0s 862us/step - loss: 0.6074 - accuracy: 0.7576 - val_loss: 0.6074 - val_accuracy: 0.7606
# Epoch 38/50
# 225/225 [==============================] - 0s 862us/step - loss: 0.6052 - accuracy: 0.7565 - val_loss: 0.5977 - val_accuracy: 0.7567
# Epoch 39/50
# 225/225 [==============================] - 0s 906us/step - loss: 0.6020 - accuracy: 0.7592 - val_loss: 0.5947 - val_accuracy: 0.7667
# Epoch 40/50
# 225/225 [==============================] - 0s 879us/step - loss: 0.6024 - accuracy: 0.7593 - val_loss: 0.5907 - val_accuracy: 0.7717
# Epoch 41/50
# 225/225 [==============================] - 0s 920us/step - loss: 0.5993 - accuracy: 0.7632 - val_loss: 0.5946 - val_accuracy: 0.7683
# Epoch 42/50
# 225/225 [==============================] - 0s 888us/step - loss: 0.5958 - accuracy: 0.7617 - val_loss: 0.5911 - val_accuracy: 0.7661
# Epoch 43/50
# 225/225 [==============================] - 0s 924us/step - loss: 0.5958 - accuracy: 0.7621 - val_loss: 0.5883 - val_accuracy: 0.7678
# Epoch 44/50
# 225/225 [==============================] - 0s 902us/step - loss: 0.5918 - accuracy: 0.7631 - val_loss: 0.5876 - val_accuracy: 0.7683
# Epoch 45/50
# 225/225 [==============================] - 0s 839us/step - loss: 0.5918 - accuracy: 0.7590 - val_loss: 0.5954 - val_accuracy: 0.7722
# Epoch 46/50
# 225/225 [==============================] - 0s 920us/step - loss: 0.5909 - accuracy: 0.7640 - val_loss: 0.5823 - val_accuracy: 0.7761
# Epoch 47/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.5848 - accuracy: 0.7646 - val_loss: 0.5926 - val_accuracy: 0.7517
# Epoch 48/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.5871 - accuracy: 0.7638 - val_loss: 0.5837 - val_accuracy: 0.7700
# Epoch 49/50
# 225/225 [==============================] - 0s 866us/step - loss: 0.5839 - accuracy: 0.7658 - val_loss: 0.5842 - val_accuracy: 0.7772
# Epoch 50/50
# 225/225 [==============================] - 0s 857us/step - loss: 0.5817 - accuracy: 0.7685 - val_loss: 0.5727 - val_accuracy: 0.7778

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred_nn = model.predict(x_test_nn)

# %%
y_pred_nn
# Out:
# array([[9.9601310e-01, 9.9075031e-01, 9.6210569e-01, 3.9220509e-01,
#         4.2295419e-06, 1.0494506e-05],
#        [1.8934715e-01, 9.6855116e-01, 9.8219413e-01, 8.8394690e-01,
#         2.1693273e-07, 2.7866037e-05],
#        [9.9968398e-01, 9.9483985e-01, 9.6858704e-01, 6.6687983e-01,
#         3.0342669e-08, 9.2746836e-07],
#        ...,
#        [1.6767085e-03, 6.4620197e-01, 9.4164085e-01, 9.4834238e-01,
#         1.4526725e-02, 5.0993353e-06],
#        [9.6011627e-01, 9.2385077e-01, 8.8181710e-01, 6.4741051e-01,
#         8.7681496e-05, 6.0409307e-04],
#        [9.9981141e-01, 9.9798548e-01, 9.8199809e-01, 5.5770808e-01,
#         6.4836452e-09, 1.5423923e-07]], dtype=float32)

# %% [markdown]
# ### Model Evaluation
#
# Evaluating the model accuracy is an essential part of the process in creating machine learning models to describe how well the model is performing in its predictions. Evaluation metrics change according to the problem type. Here, we'll briefly learn how to check the accuracy of the regression model.
#
# The linear model (regression) can be a typical example of this type of problem, and the main characteristic of the regression problem is that the targets of a dataset contain the real numbers only. The errors represent how much the model is making mistakes in its prediction. The basic concept of accuracy evaluation is to compare the original target with the predicted one according to certain metrics.
#
#
# **Regression model evaluation metrics**
#
# The MAE, RMSE, and R-Squared metrics are mainly used to evaluate the prediction error rates and model performance in regression analysis.
#
# **MAE (Mean absolute error)** represents the difference between the original and predicted values extracted by averaged the absolute difference over the data set.
#
# **RMSE (Root Mean Squared Error)** is the error rate by the square root of MSE.
#
# **R-squared (Coefficient of determination)** represents the coefficient of how well the values fit compared to the original values. The value from 0 to 1 interpreted as percentages. The higher the value is, the better the model is.
#
# The above metrics can be expressed as following:
# <img src = "https://4.bp.blogspot.com/-wG7IbjTfE6k/XGUvqm7TCVI/AAAAAAAAAZU/vpH1kuKTIooKTcVlnm1EVRCXLVZM9cPNgCLcBGAs/s1600/formula-MAE-MSE-RMSE-RSquared.JPG">
#
# Please find more information on how to implement them from this link: https://scikit-learn.org/stable/modules/classes.html#regression-metrics
#
# Find more about feature importances from here: https://machinelearningmastery.com/calculate-feature-importance-with-python/
#
# **Classification model evaluation metrics**
#
# <img src="https://www.researchgate.net/publication/336402347/figure/fig3/AS:812472659349505@1570719985505/Calculation-of-Precision-Recall-and-Accuracy-in-the-confusion-matrix.ppm">

# %% [markdown]
# *TODO*
# **For Regression models**
# <li>Use three metrics: R-squared, RMSE, and MAE, to evaluate model prediction performance</li>
# <li>Compare these 3 metrics for the two models and analyze the performance</li>
# <li>Calculate the feature importance scores for the top features that help predicting wine quality and visualize them</li>

# %% [markdown]
# ### Support Vector Machine Metrics

# %%
# R Squared
def r_squared(y_test, y_pred):
    y_mean = np.mean(y_test)
    y_sum_predicted = np.sum((y_test - y_pred)**2)
    y_sum_mean = np.sum((y_test - y_mean)**2)
    r_squared = 1 - (y_sum_predicted / y_sum_mean)
    return r_squared

# %%
y_test
# Out:
# 1330    6
# 597     6
# 1203    5
# 664     5
# 47      5
#        ..
# 320     7
# 1537    6
# 158     5
# 890     5
# 1568    5
# Name: quality, Length: 291, dtype: int64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
# import numpy as np

print("SVM MAE: {}".format(np.sqrt(mean_absolute_error(y_test, y_pred_svc))))
print("SVM RMSE: {}".format(mean_squared_error(y_test, y_pred_svc)))
print("SVM R-Squared: {}".format(r_squared(y_test, y_pred_svc)))
# Out:
# SVM MAE: 0.6755846853836197
# SVM RMSE: 0.4005205516629632
# SVM R-Squared: 0.28737906384478307

# %%
from sklearn.inspection import permutation_importance
import numpy as np
import matplotlib.pyplot as plt

perm_importance = permutation_importance(best_svc, X_test, y_test)

feature_names = wine_data.columns
features = np.array(feature_names)

sorted_idx = perm_importance.importances_mean.argsort()
plt.barh(features[sorted_idx], perm_importance.importances_mean[sorted_idx])
plt.xlabel("Relative Importance")
# Out:
# Text(0.5, 0, 'Relative Importance')

# %%
type(np.array(wine_data.columns))
# Out:
# numpy.ndarray

# %% [markdown]
# ### Random Forest Metrics

# %%
print("Random Forest MAE: {}".format(np.sqrt(mean_absolute_error(y_test, y_pred_rf))))
print("Random Forest RMSE: {}".format(mean_squared_error(y_test, y_pred_rf)))
print("Random Forest R-Squared: {}".format(r_squared(y_test, y_pred_rf)))
# Out:
# Random Forest MAE: 0.6696847889940567
# Random Forest RMSE: 0.3662317697582037
# Random Forest R-Squared: 0.3483869291319398

# %%
temp_wine_data = pd.get_dummies(wine_data)
display(rf.feature_importances_)

features = temp_wine_data.columns
importances = rf_temp.feature_importances_
indices = np.argsort(importances)[:]
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices])
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Importance')
plt.show()
# Out:
# array([0.04448698, 0.10032957, 0.05740936, 0.05181234, 0.06323481,
#        0.03880475, 0.07802551, 0.05315627, 0.0585526 , 0.14515765,
#        0.30903018])

# %%
features
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# **For Classification model**
# <li> Plot training loss and validation loss </li>
# <li> Plot training accuracy and validation accuracy </li>
# <li> Evaluate the classsification model using Precision, Recall and Accuracy metrics </li>

# %% [markdown]
# #### Training Loss and Validation Loss (where loss is expressed in MAE)

# %%
plt.plot(history.history['loss'], label='MAE training data')
plt.plot(history.history['val_loss'], label='MAE validation data')
plt.legend()
plt.title('MAE for model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# #### Training Accuracy and Validation Accuracy

# %%
plt.plot(history.history['accuracy'], label='Accuracy training data')
plt.plot(history.history['val_accuracy'], label='Accuracy validation data')
plt.legend()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# #### Accuracy, Precision, and Recall

# %%
discrete_y_pred_nn = []

for e in y_pred_nn:
    discrete_y_pred_nn.append(np.argmax(e))

len(discrete_y_pred_nn)
# Out:
# 1800

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy = round(accuracy_score(y_test_nn, discrete_y_pred_nn), 3)
precision = round(precision_score(y_test_nn, discrete_y_pred_nn, average='macro'), 3)
recall = round(recall_score(y_test_nn, discrete_y_pred_nn, average='macro'), 3)

print("accuracy: {}".format(accuracy))
print("precision: {}".format(precision))
print("recall: {}".format(precision))
# Out:
# accuracy: 0.778
# precision: 0.767
# recall: 0.767

# %% [markdown]
# ### Conclusion
#
# *TODO*
#
# In conclusion, based on the features derived from the Random Forest Regression Model, the most important feature seems to be alcohol, suphates, and volatile acidity. Whereas, the least important features seem to be free sulfur dioxide, fixed acidity, and density. On the otherhand, the most important features dictated by the SVM models seem to alcohol, volatile, acidity and suphates. Whereas, the least important are chlorides, pH, and free sulfur dioxide. Since, the same set of features are indicated as the most important by both models, we can say that the most important factors in wine creation are alcohol, suphates, and the volatile acidity.

# %% [markdown]
# ## Extra Section: Results from Removing Features indicated in the SVM model.

# %%
wine_data = pd.read_csv("winequality-red.csv", sep=",")
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
from scipy import stats
import numpy as np

z = np.abs(stats.zscore(wine_data))

threshold = 3
wine_data = wine_data[(z < threshold).all(axis=1)]
wine_data.shape
# Out:
# (1451, 12)

# %%
x = wine_data.drop(['quality'] , axis = 1)

# %% [markdown]
# ### Here we remove the features corresponding to the least important as dictated by the trained SVM model

# %%
del x['density']
del x['pH']
del x['free sulfur dioxide']

# %%
from collections import Counter

le = LabelEncoder()
y = le.fit_transform(wine_data.iloc[: , -1]) # in row form
print(Counter(y))
y = pd.DataFrame(y.reshape(len(y),1))
# Out:
# Counter({1: 617, 2: 586, 3: 185, 0: 47, 4: 16})

# %%
from imblearn.over_sampling import SMOTE

sample_size = 1800
oversample = SMOTE(sampling_strategy={0: sample_size, 1: sample_size, 2: sample_size, 3: sample_size, 4: sample_size})
x, y = oversample.fit_resample(x, y)
# Out:
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 0 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 1 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 2 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 3 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(
# C:\Users\Francis Dave\AppData\Roaming\Python\Python39\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (1800) in class 4 will be larger than the number of samples in the majority class (class #1 -> 617)
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
n_classes = 6 # because we only have 6 categories
y_train_cat = tf.keras.utils.to_categorical(y_train, n_classes)
y_test_cat = tf.keras.utils.to_categorical(y_test, n_classes)

# %%
sc = StandardScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
model = Sequential()
model.add(Dense(16, activation='relu', input_shape=(8,)))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(6, activation='sigmoid'))

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics= ['accuracy'])

# %%
history = model.fit(x_train, y_train_cat,  batch_size= 32, epochs = 50 , validation_data = (x_test, y_test_cat))
# Out:
# Epoch 1/50
# 225/225 [==============================] - 1s 1ms/step - loss: 1.5152 - accuracy: 0.3504 - val_loss: 1.2237 - val_accuracy: 0.4733
# Epoch 2/50
# 225/225 [==============================] - 0s 839us/step - loss: 1.1320 - accuracy: 0.4933 - val_loss: 1.0498 - val_accuracy: 0.5700
# Epoch 3/50
# 225/225 [==============================] - 0s 929us/step - loss: 1.0416 - accuracy: 0.5421 - val_loss: 0.9940 - val_accuracy: 0.5628
# Epoch 4/50
# 225/225 [==============================] - 0s 893us/step - loss: 0.9980 - accuracy: 0.5664 - val_loss: 0.9594 - val_accuracy: 0.5928
# Epoch 5/50
# 225/225 [==============================] - 0s 893us/step - loss: 0.9639 - accuracy: 0.5813 - val_loss: 0.9238 - val_accuracy: 0.5950
# Epoch 6/50
# 225/225 [==============================] - 0s 933us/step - loss: 0.9346 - accuracy: 0.5962 - val_loss: 0.8999 - val_accuracy: 0.6056
# Epoch 7/50
# 225/225 [==============================] - 0s 871us/step - loss: 0.9070 - accuracy: 0.6161 - val_loss: 0.8847 - val_accuracy: 0.6078
# Epoch 8/50
# 225/225 [==============================] - 0s 835us/step - loss: 0.8826 - accuracy: 0.6199 - val_loss: 0.8541 - val_accuracy: 0.6267
# Epoch 9/50
# 225/225 [==============================] - 0s 866us/step - loss: 0.8611 - accuracy: 0.6331 - val_loss: 0.8468 - val_accuracy: 0.6361
# Epoch 10/50
# 225/225 [==============================] - 0s 911us/step - loss: 0.8445 - accuracy: 0.6446 - val_loss: 0.8244 - val_accuracy: 0.6317
# Epoch 11/50
# 225/225 [==============================] - 0s 911us/step - loss: 0.8272 - accuracy: 0.6536 - val_loss: 0.8225 - val_accuracy: 0.6406
# Epoch 12/50
# 225/225 [==============================] - 0s 911us/step - loss: 0.8145 - accuracy: 0.6583 - val_loss: 0.8058 - val_accuracy: 0.6489
# Epoch 13/50
# 225/225 [==============================] - 0s 938us/step - loss: 0.8006 - accuracy: 0.6686 - val_loss: 0.7881 - val_accuracy: 0.6628
# Epoch 14/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.7876 - accuracy: 0.6703 - val_loss: 0.7845 - val_accuracy: 0.6667
# Epoch 15/50
# 225/225 [==============================] - 0s 879us/step - loss: 0.7785 - accuracy: 0.6774 - val_loss: 0.7727 - val_accuracy: 0.6628
# Epoch 16/50
# 225/225 [==============================] - 0s 911us/step - loss: 0.7670 - accuracy: 0.6826 - val_loss: 0.7571 - val_accuracy: 0.6706
# Epoch 17/50
# 225/225 [==============================] - 0s 924us/step - loss: 0.7577 - accuracy: 0.6818 - val_loss: 0.7544 - val_accuracy: 0.6739
# Epoch 18/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.7494 - accuracy: 0.6911 - val_loss: 0.7459 - val_accuracy: 0.6750
# Epoch 19/50
# 225/225 [==============================] - 0s 848us/step - loss: 0.7390 - accuracy: 0.6931 - val_loss: 0.7344 - val_accuracy: 0.6867
# Epoch 20/50
# 225/225 [==============================] - 0s 862us/step - loss: 0.7330 - accuracy: 0.6983 - val_loss: 0.7340 - val_accuracy: 0.6872
# Epoch 21/50
# 225/225 [==============================] - 0s 906us/step - loss: 0.7259 - accuracy: 0.7024 - val_loss: 0.7205 - val_accuracy: 0.6917
# Epoch 22/50
# 225/225 [==============================] - 0s 857us/step - loss: 0.7185 - accuracy: 0.7071 - val_loss: 0.7192 - val_accuracy: 0.6878
# Epoch 23/50
# 225/225 [==============================] - 0s 853us/step - loss: 0.7119 - accuracy: 0.7086 - val_loss: 0.7047 - val_accuracy: 0.7011
# Epoch 24/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.7043 - accuracy: 0.7118 - val_loss: 0.7053 - val_accuracy: 0.7011
# Epoch 25/50
# 225/225 [==============================] - 0s 844us/step - loss: 0.6979 - accuracy: 0.7157 - val_loss: 0.6976 - val_accuracy: 0.7044
# Epoch 26/50
# 225/225 [==============================] - 0s 835us/step - loss: 0.6936 - accuracy: 0.7190 - val_loss: 0.6925 - val_accuracy: 0.7022
# Epoch 27/50
# 225/225 [==============================] - 0s 879us/step - loss: 0.6909 - accuracy: 0.7149 - val_loss: 0.6888 - val_accuracy: 0.7089
# Epoch 28/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.6852 - accuracy: 0.7174 - val_loss: 0.6891 - val_accuracy: 0.7139
# Epoch 29/50
# 225/225 [==============================] - 0s 862us/step - loss: 0.6803 - accuracy: 0.7250 - val_loss: 0.6853 - val_accuracy: 0.7100
# Epoch 30/50
# 225/225 [==============================] - 0s 902us/step - loss: 0.6775 - accuracy: 0.7282 - val_loss: 0.6765 - val_accuracy: 0.7206
# Epoch 31/50
# 225/225 [==============================] - 0s 866us/step - loss: 0.6726 - accuracy: 0.7300 - val_loss: 0.6762 - val_accuracy: 0.7194
# Epoch 32/50
# 225/225 [==============================] - 0s 853us/step - loss: 0.6688 - accuracy: 0.7307 - val_loss: 0.6740 - val_accuracy: 0.7150
# Epoch 33/50
# 225/225 [==============================] - 0s 1ms/step - loss: 0.6675 - accuracy: 0.7322 - val_loss: 0.6693 - val_accuracy: 0.7122
# Epoch 34/50
# 225/225 [==============================] - 0s 857us/step - loss: 0.6640 - accuracy: 0.7336 - val_loss: 0.6647 - val_accuracy: 0.7272
# Epoch 35/50
# 225/225 [==============================] - 0s 871us/step - loss: 0.6606 - accuracy: 0.7306 - val_loss: 0.6686 - val_accuracy: 0.7178
# Epoch 36/50
# 225/225 [==============================] - 0s 835us/step - loss: 0.6592 - accuracy: 0.7350 - val_loss: 0.6582 - val_accuracy: 0.7267
# Epoch 37/50
# 225/225 [==============================] - 0s 875us/step - loss: 0.6547 - accuracy: 0.7392 - val_loss: 0.6571 - val_accuracy: 0.7222
# Epoch 38/50
# 225/225 [==============================] - 0s 853us/step - loss: 0.6524 - accuracy: 0.7371 - val_loss: 0.6627 - val_accuracy: 0.7311
# Epoch 39/50
# 225/225 [==============================] - 0s 866us/step - loss: 0.6502 - accuracy: 0.7393 - val_loss: 0.6532 - val_accuracy: 0.7289
# Epoch 40/50
# 225/225 [==============================] - 0s 871us/step - loss: 0.6474 - accuracy: 0.7400 - val_loss: 0.6581 - val_accuracy: 0.7272
# Epoch 41/50
# 225/225 [==============================] - 0s 857us/step - loss: 0.6451 - accuracy: 0.7393 - val_loss: 0.6484 - val_accuracy: 0.7328
# Epoch 42/50
# 225/225 [==============================] - 0s 911us/step - loss: 0.6445 - accuracy: 0.7399 - val_loss: 0.6491 - val_accuracy: 0.7294
# Epoch 43/50
# 225/225 [==============================] - 0s 879us/step - loss: 0.6412 - accuracy: 0.7396 - val_loss: 0.6451 - val_accuracy: 0.7250
# Epoch 44/50
# 225/225 [==============================] - 0s 937us/step - loss: 0.6385 - accuracy: 0.7399 - val_loss: 0.6484 - val_accuracy: 0.7261
# Epoch 45/50
# 225/225 [==============================] - 0s 929us/step - loss: 0.6355 - accuracy: 0.7425 - val_loss: 0.6473 - val_accuracy: 0.7311
# Epoch 46/50
# 225/225 [==============================] - 0s 871us/step - loss: 0.6344 - accuracy: 0.7407 - val_loss: 0.6497 - val_accuracy: 0.7283
# Epoch 47/50
# 225/225 [==============================] - 0s 853us/step - loss: 0.6325 - accuracy: 0.7435 - val_loss: 0.6381 - val_accuracy: 0.7389
# Epoch 48/50
# 225/225 [==============================] - 0s 835us/step - loss: 0.6307 - accuracy: 0.7432 - val_loss: 0.6493 - val_accuracy: 0.7256
# Epoch 49/50
# 225/225 [==============================] - 0s 902us/step - loss: 0.6274 - accuracy: 0.7437 - val_loss: 0.6396 - val_accuracy: 0.7378
# Epoch 50/50
# 225/225 [==============================] - 0s 857us/step - loss: 0.6257 - accuracy: 0.7443 - val_loss: 0.6368 - val_accuracy: 0.7328

# %%
plt.plot(history.history['loss'], label='MAE training data')
plt.plot(history.history['val_loss'], label='MAE validation data')
plt.legend()
plt.title('MAE for model')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['accuracy'], label='Accuracy training data')
plt.plot(history.history['val_accuracy'], label='Accuracy validation data')
plt.legend()
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.show()
